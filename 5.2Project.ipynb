# %% [markdown]
#  American Ninja Warrior Obstacle History Project - 6/30/2024 - angort8476

# %%
# Import necessary libraries
import pandas as pd
from datetime import datetime
from IPython.display import display, Markdown

todays_date = datetime.now().strftime("%Y-%m-%d")
student_id = "angort8476"

# Load the dataset from an Excel file into a pandas DataFrame. 
data = pd.read_excel('C:/Users/angel/OneDrive/Documents/ECPI/DataAnalyticsMethodsandModeling_LAB_B.Erb\WEEK1/1.3Project_Part1/American Ninja Warrior Obstacle History.xlsx')

# Display the first few rows to understand what the data looks like.
display(f"Date: {todays_date}") 
display(f"Student ID: {student_id}") 
display(data.head())
# Out:
# 'Date: 2024-07-21'
# 'Student ID: angort8476'
#                   Unnamed: 0      Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                        NaN             NaN        NaN         NaN
# 1     Count of Obstacle Name   Column Labels        NaN         NaN
# 2                 Row Labels  Floating Steps   Log Grip  Quad Steps
# 3     Finals (Regional/City)              11          9           6
# 4  National Finals - Stage 1             NaN          1         NaN
#
#       Unnamed: 4   Unnamed: 5   Unnamed: 6
# 0            NaN          NaN          NaN
# 1            NaN          NaN          NaN
# 2  Salmon Ladder  Warped Wall  Grand Total
# 3             38           38          102
# 4            NaN           10           11

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime

df = pd.read_excel('C:/Users/angel/OneDrive/Documents/ECPI/DataAnalyticsMethodsandModeling_LAB_B.Erb\WEEK1/1.3Project_Part1/Obstacle Analitics.xlsx')
top_10_Obstacles = df.nlargest(10, 'Count')
plt.figure(figsize=(12, 8))
plt.barh(top_10_Obstacles['Obstacle Name'],
top_10_Obstacles['Count'], color='Red')
plt.xlabel('Count of Obstacle Name')
plt.ylabel('Obstacle Name')
plt.title(f'Top 10 Obstacles by Count of Obstacle Name - StudentID: {student_id} - {todays_date}')
plt.gca().invert_yaxis()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime
student_id = "angort8476"
# Get current date and time
current_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
plt.figure(figsize=(10, 6))
plt.hist(df['Count'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Count of times an obstacle has been reused ')
plt.ylabel('Number of obstacles')
plt.title(f'Histogram of Number of Obtacles vs. Count of Obstacle Name - StudentID: {student_id} - {current_datetime}')
plt.grid(True)
plt.show()

# %%
import matplotlib
plotdata = pd.DataFrame({
    "Floating Steps":[11, 0, 0, 0, 17, 0],
    "Long Grip":[9, 1, 0, 1, 9, 1],
    "Quad Steps":[6, 0, 0, 2, 6, 2],
    "Salmon Ladder":[38, 0, 1, 0, 0, 2],
    "Warped Wall":[38, 10, 0, 3, 32, 3]
    }, 
    index=["Finals (Regional/City)", "National Finals - Stage 1", "National Finals - Stage 2", "Qualifying", "Qualifying (Regional/City)", "Semi-Finals"] )
plotdata.plot(kind="bar")
matplotlib.style.use('fivethirtyeight')
plt.title("Count of apperance of obstacle name by stage ")
plt.xlabel("Stage")
plt.ylabel("")
plotdata.head()
# Out:
#                             Floating Steps  Long Grip  Quad Steps  \
# Finals (Regional/City)                  11          9           6
# National Finals - Stage 1                0          1           0
# National Finals - Stage 2                0          0           0
# Qualifying                               0          1           2
# Qualifying (Regional/City)              17          9           6
#
#                             Salmon Ladder  Warped Wall
# Finals (Regional/City)                 38           38
# National Finals - Stage 1               0           10
# National Finals - Stage 2               1            0
# Qualifying                              0            3
# Qualifying (Regional/City)              0           32

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime

df = pd.read_excel('C:/Users/angel/OneDrive/Documents/ECPI/DataAnalyticsMethodsandModeling_LAB_B.Erb\WEEK1/1.3Project_Part1/Obstacle Analitics.xlsx')
top_10_Obstacles = df.nlargest(10, 'Count')

top_10_Obstacles.describe()
# Out:
#            Count
# count  10.000000
# mean   27.800000
# std    22.646069
# min    11.000000
# 25%    14.500000
# 50%    19.500000
# 75%    31.000000
# max    86.000000
